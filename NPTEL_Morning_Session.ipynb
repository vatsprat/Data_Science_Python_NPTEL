# %%
import pandas as pd

# %%
df=pd.read_csv("apy_1.csv",index_col=0)

# %%
df.head()
# Out:
#       State_Name  District_Name  Crop_Year       Season       Crop     Area  \
# 0          Bihar        NALANDA       1997  Rabi             Wheat  81934.0
# 1          Assam  KARBI ANGLONG       2011  Whole Year       Onion    257.0
# 2        Gujarat          ANAND       2012  Summer           Maize    100.0
# 3      Karnataka   UTTAR KANNAD       2005  Rabi         Groundnut   2872.0
# 4  Uttar Pradesh        JAUNPUR       2008  Rabi             Onion    110.0
#
#    Production
# 0    160425.0
# 1       514.0
# 2       100.0
# 3      4572.0
# 4      1290.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73827 entries, 0 to 73826
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State_Name     73827 non-null  object
#  1   District_Name  73827 non-null  object
#  2   Crop_Year      73827 non-null  int64
#  3   Season         73827 non-null  object
#  4   Crop           73827 non-null  object
#  5   Area           73827 non-null  float64
#  6   Production     72731 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 4.5+ MB

# %%
import numpy as np

# %%
print(np.unique(df['State_Name']))
# Out:
# ['Andaman and Nicobar Islands' 'Andhra Pradesh' 'Arunachal Pradesh'
#  'Assam' 'Bihar' 'Chandigarh' 'Chhattisgarh' 'Dadra and Nagar Haveli'
#  'Goa' 'Gujarat' 'Haryana' 'Himachal Pradesh' 'Jammu and Kashmir '
#  'Jharkhand' 'Karnataka' 'Kerala' 'Madhya Pradesh' 'Maharashtra' 'Manipur'
#  'Meghalaya' 'Mizoram' 'Nagaland' 'Odisha' 'Puducherry' 'Punjab'
#  'Rajasthan' 'Sikkim' 'Tamil Nadu' 'Telangana ' 'Tripura' 'Uttar Pradesh'
#  'Uttarakhand' 'West Bengal']

# %%
df.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       1096
# dtype: int64

# %%
df.dropna()
# Out:
#            State_Name  District_Name  Crop_Year       Season       Crop  \
# 0               Bihar        NALANDA       1997  Rabi             Wheat
# 1               Assam  KARBI ANGLONG       2011  Whole Year       Onion
# 2             Gujarat          ANAND       2012  Summer           Maize
# 3           Karnataka   UTTAR KANNAD       2005  Rabi         Groundnut
# 4       Uttar Pradesh        JAUNPUR       2008  Rabi             Onion
# ...               ...            ...        ...          ...        ...
# 73822           Bihar          BUXAR       2004  Whole Year       Onion
# 73823  Madhya Pradesh        RAJGARH       2013  Kharif           Bajra
# 73824  Madhya Pradesh        RAJGARH       1998  Kharif       Groundnut
# 73825       Rajasthan           TONK       2000  Kharif           Bajra
# 73826       Jharkhand        KODERMA       2002  Winter            Rice
#
#            Area  Production
# 0      81934.00   160425.00
# 1        257.00      514.00
# ...

# %%
df.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       1096
# dtype: int64

# %%
print(np.unique(df['Production']))
# Out:
# [0.000e+00 1.000e-02 2.000e-02 ... 9.350e+08 1.125e+09       nan]

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
df.groupby('Season')['Production'].sum()
# Out:
# Season
# Autumn         1.969044e+07
# Kharif         1.195933e+09
# Rabi           6.151127e+08
# Summer         4.920665e+07
# Whole Year     4.315616e+10
# Winter         1.321746e+08
# Name: Production, dtype: float64

# %%
g=df.groupby(['Season'])

# %%
g

# %%
g.count()
# Out:
#              State_Name  District_Name  Crop_Year   Crop   Area  Production
# Season
# Autumn             1484           1484       1484   1484   1484        1484
# Kharif            28256          28256      28256  28256  28256       28256
# Rabi              19918          19918      19918  19918  19918       19918
# Summer             4418           4418       4418   4418   4418        4418
# Whole Year        16821          16821      16821  16821  16821       16821
# Winter             1834           1834       1834   1834   1834        1834

# %%
for g,g_df in g:
    print(g)
    print(g_df)
# Out:
# Autumn
#         State_Name District_Name  Crop_Year       Season   Crop      Area  \
# 23           Assam      TINSUKIA       2012  Autumn        Rice   5806.00
# 56          Kerala     KASARAGOD       2010  Autumn        Rice   2283.99
# 70          Kerala        IDUKKI       2010  Autumn        Rice    418.33
# 143         Odisha         BOUDH       2009  Autumn       Maize    360.00
# 180      Jharkhand         PAKUR       2005  Autumn       Maize   2459.70
# ...            ...           ...        ...          ...    ...       ...
# 73488       Odisha       BARGARH       2007  Autumn        Rice  62000.00
# 73685        Assam      MARIGAON       2007  Autumn        Rice   4872.00
# 73694       Odisha      GAJAPATI       2000  Autumn        Rice   1750.00
# 73720  Maharashtra          PUNE       1997  Autumn       Maize      4.00
# 73721        Bihar        ARARIA       2013  Autumn       Maize   9917.00
#
#        Production
# 23        7964.00
# 56        5824.31
# ...

# %%
df["Season"].unique()
# Out:
# array(['Rabi       ', 'Whole Year ', 'Summer     ', 'Winter     ',
#        'Kharif     ', 'Autumn     '], dtype=object)

# %%
df[df["Season"]=="Whole Year "].groupby(['Crop']).count().head(50)
# Out:
#                            State_Name  District_Name  Crop_Year  Season  Area  \
# Crop
# Apple                               2              2          2       2     2
# Arcanut (Processed)                 6              6          6       6     6
# Arecanut                          453            453        453     453   453
# Arhar/Tur                          70             70         70      70    70
# Ash Gourd                          18             18         18      18    18
# Atcanut (Raw)                       5              5          5       5     5
# Bajra                              52             52         52      52    52
# Banana                            859            859        859     859   859
# Barley                             15             15         15      15    15
# Beans & Mutter(Vegetable)          50             50         50      50    50
# Beet Root                           6              6          6       6     6
# ...

# %%
df['Season']=df['Season'].astype('category')

# %%
df["Season"].unique()
# Out:
# ['Rabi       ', 'Whole Year ', 'Summer     ', 'Winter     ', 'Kharif     ', 'Autumn     ']
# Categories (6, object): ['Autumn     ', 'Kharif     ', 'Rabi       ', 'Summer     ', 'Whole Year ', 'Winter     ']

# %%
df['Season']=df['Season'].astype('object')

# %%
df["Season"].unique()
# Out:
# array(['Rabi       ', 'Whole Year ', 'Summer     ', 'Winter     ',
#        'Kharif     ', 'Autumn     '], dtype=object)

# %%
df[df["Season"]=="Whole Year "].groupby(['Crop']).value_counts()
# Out:
# Crop                 State_Name                   District_Name   Crop_Year  Season       Area     Production
# Apple                Tamil Nadu                   DINDIGUL        2002       Whole Year   3.00     0.00          1
#                                                                   2003       Whole Year   4.00     0.00          1
# Arcanut (Processed)  Karnataka                    BELLARY         2002       Whole Year   30.00    43.00         1
#                                                   CHAMARAJANAGAR  2002       Whole Year   279.00   198.00        1
#                                                   KODAGU          2002       Whole Year   1332.00  1863.00       1
#                                                                                                                 ..
# other oilseeds       Andaman and Nicobar Islands  SOUTH ANDAMANS  2006       Whole Year   24.00    14.98         1
# ...

# %%
df.groupby(["District_Name"])["Production"].sum().sort_values()
# Out:
# District_Name
# MUMBAI                2.000000e+00
# HYDERABAD             3.060000e+02
# NAMSAI                7.940000e+02
# RAMGARH               8.930000e+02
# RAMBAN                1.578000e+03
#                           ...
# THIRUVANANTHAPURAM    2.963416e+09
# KASARAGOD             3.479150e+09
# THRISSUR              3.681628e+09
# MALAPPURAM            4.375478e+09
# KOZHIKODE             6.012791e+09
# Name: Production, Length: 646, dtype: float64

# %%
df[df['State_Name']=='West Bengal'].groupby(['Crop_Year'])['Production'].sum().sort_values()
# Out:
# Crop_Year
# 2001      7689550.7
# 2000      8323849.0
# 2004      8608367.5
# 1999      9195580.0
# 2005      9494050.0
# 1998      9988608.3
# 2008     10030521.0
# 2011     10949803.0
# 2010     12338035.0
# 2002     12559002.1
# 2013     13494606.0
# 2012     13498244.0
# 2003     14170705.6
# 2009     14476077.0
# 2014     18302156.0
# 1997     22472430.0
# 2006    173250298.0
# 2007    201537048.0
# Name: Production, dtype: float64

# %%
df.groupby(['State_Name'])['Production'].sum().sort_values()
# Out:
# State_Name
# Chandigarh                     2.923000e+04
# Mizoram                        4.704351e+05
# Sikkim                         6.453750e+05
# Dadra and Nagar Haveli         6.919730e+05
# Manipur                        1.560800e+06
# Arunachal Pradesh              2.181652e+06
# Nagaland                       3.340025e+06
# Jharkhand                      3.416858e+06
# Jammu and Kashmir              3.870168e+06
# Tripura                        3.975350e+06
# Meghalaya                      4.059699e+06
# Himachal Pradesh               5.828741e+06
# Chhattisgarh                   3.260849e+07
# Uttarakhand                    3.685920e+07
# Odisha                         4.635979e+07
# Puducherry                     7.539482e+07
# Rajasthan                      8.756090e+07
# Haryana                        9.644999e+07
# Telangana                      9.946250e+07
# Bihar                          1.125670e+08
# Madhya Pradesh                 1.300390e+08
# ...

# %%
df['Area'].corr(df['Production'])
# Out:
# 0.04104337559515248

# %%
df['Production'].mean()
# Out:
# 621031.9533575787

# %%
df['Production'].std()
# Out:
# 17497558.28783266

# %%
df[df['Crop_Year']==2015].groupby(['State_Name'])['Production'].count()
# Out:
# State_Name
# Odisha    172
# Sikkim      8
# Name: Production, dtype: int64

# %%
df[df['Crop_Year']==2005].groupby(['Crop'])['Production'].sum().sort_values()
# Out:
# Crop
# other oilseeds             1.320000e+02
# Cardamom                   6.330000e+02
# Sannhamp                   1.520500e+03
# Oilseeds total             4.066000e+03
# Other Cereals & Millets    1.771840e+04
# Niger seed                 2.178100e+04
# Cashewnut                  2.552022e+04
# Other  Rabi pulses         3.138100e+04
# Black pepper               3.699095e+04
# Linseed                    4.511500e+04
# Other Kharif pulses        4.870190e+04
# Horse-gram                 5.050140e+04
# Moth                       5.253100e+04
# Peas & beans (Pulses)      6.438700e+04
# Tobacco                    7.230860e+04
# Small millets              9.555200e+04
# Castor seed                9.884800e+04
# Turmeric                   1.023300e+05
# Coriander                  1.072420e+05
# Safflower                  1.135730e+05
# Masoor                     1.199445e+05
# Khesari                    1.374330e+05
# Sweet potato               1.395124e+05
# ...

# %%
df['Crop_Year'].corr(df['Production'])
# Out:
# 0.007421579179499451

# %%
df['Crop_Year'].corr(df['Area'])
# Out:
# -0.023267211337651774

# %%
df.groupby(['Crop_Year'])['Production'].sum().sort_values()
# Out:
# Crop_Year
# 2015    2.114047e+06
# 1997    2.768054e+08
# 1998    5.356398e+08
# 2014    1.390088e+09
# 2003    1.394080e+09
# 2007    1.771568e+09
# 1999    1.873175e+09
# 2000    1.964593e+09
# 2013    2.023688e+09
# 2008    2.088889e+09
# 2002    2.616621e+09
# 2010    2.654638e+09
# 2005    2.892020e+09
# 2001    3.086705e+09
# 2006    3.709813e+09
# 2009    3.739178e+09
# 2012    3.876649e+09
# 2004    3.896185e+09
# 2011    5.375825e+09
# Name: Production, dtype: float64

# %%
df[df['State_Name']=="Maharashtra"].groupby(['Crop'])['Production'].sum().sort_values()
# Out:
# Crop
# Tobacco                         2100.0
# Pulses total                    3173.0
# other oilseeds                  4500.0
# Rapeseed &Mustard              12999.0
# Castor seed                    15151.5
# Total foodgrain                28818.0
# Other Cereals & Millets        42500.0
# Linseed                        42612.0
# Tomato                         57970.0
# Small millets                  76400.0
# Niger seed                     76692.0
# Sesamum                       107764.0
# Other  Rabi pulses            148552.0
# Grapes                        152147.0
# Other Kharif pulses           169240.0
# Mango                         195730.0
# Safflower                     605498.0
# Sunflower                     670642.0
# Ragi                          860385.0
# Banana                        862240.0
# Urad                         1177100.0
# Moong(Green Gram)            1269842.0
# Onion                        1473341.0
# Groundnut                    1938415.0
# ...
